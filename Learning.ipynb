# %%
from vector_drawing import *
dino_vector = [(6,4), (3, 1), (-1, 5), (-2,5), (-3,4), (-4, 4),]

draw(
    Points(*dino_vector)
)

# %%
x=[i for i in range(-10,11 )]
y=[i**2 for i in range(-10,11 )]

points = []
for i in zip(x, y):
    points.append(i)

draw(
    Points(*points)
)
